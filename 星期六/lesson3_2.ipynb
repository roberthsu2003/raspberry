# %%
import requests
response = requests.get('https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json/preview')
if response.status_code:
    print("下載成功")

youbike = response.json()

for items in youbike:
    print(f"站名:{items['sna']}")
    print(f"總量:{items['tot']}")
    print(f"可借:{items['sbi']}")
    print(f"時間:{items['mday']}")
    print("===================\n\n")
# Out:
# 下載成功
# 站名:大鵬華城
# 總量:28
# 可借:14
# 時間:20220528115438
# ===================
#
#
# 站名:汐止火車站
# 總量:44
# 可借:40
# 時間:20220528115442
# ===================
#
#
# 站名:汐止區公所
# 總量:46
# 可借:13
# 時間:20220528115416
# ===================
#
#
# 站名:國泰綜合醫院
# 總量:48
# 可借:22
# 時間:20220528115418
# ===================
#
#
# 站名:裕隆公園
# 總量:32
# 可借:0
# 時間:20220513093721
# ===================
#
#
# 站名:捷運大坪林站(5號出口)
# 總量:78
# 可借:43
# 時間:20220528115426
# ===================
#
#
# 站名:汐科火車站(北)
# 總量:26
# 可借:15
# 時間:20220528115440
# ===================
#
#
# 站名:興華公園
# 總量:40
# 可借:26
# 時間:20220528115430
# ===================
#
#
# 站名:三重國民運動中心
# 總量:68
# 可借:33
# 時間:20220528115428
# ===================
#
#
# 站名:捷運三重站(3號出口)
# 總量:24
# 可借:6
# 時間:20220528115436
# ===================
#
#
# 站名:樟樹國小
# 總量:48
# 可借:27
# 時間:20220528115447
# ===================
#
#
# 站名:金龍國小
# 總量:52
# 可借:31
# 時間:20220528115420
# ===================
#
#
# 站名:白雲國小
# 總量:36
# 可借:17
# 時間:20220528115422
# ===================
#
#
# 站名:東勢宜興活動中心
# 總量:52
# 可借:33
# 時間:20220528115428
# ===================
#
#
# 站名:後港公園
# 總量:34
# 可借:16
# 時間:20220528115416
# ===================
#
#
# 站名:福營行政中心
# 總量:34
# 可借:10
# 時間:20220528115439
# ===================
#
#
# 站名:西盛公園
# 總量:36
# 可借:15
# 時間:20220528115438
# ===================
#
#
# 站名:忠誠里(北新路2段97巷)
# 總量:20
# 可借:7
# 時間:20220528115421
# ===================
#
#
# 站名:仁愛廣場
# 總量:50
# 可借:19
# 時間:20220528115415
# ===================
#
#
# 站名:重陽國小
# 總量:36
# 可借:10
# 時間:20220528115442
# ===================
#
#
# 站名:明志國中
# 總量:50
# 可借:16
# 時間:20220528115426
# ===================
#
#
# 站名:三重商工
# 總量:64
# 可借:26
# 時間:20220528115418
# ===================
#
#
# 站名:捷運新莊站(1號出口)
# 總量:58
# 可借:11
# 時間:20220528115426
# ===================
#
#
# 站名:原興廣場
# 總量:52
# 可借:27
# 時間:20220528115433
# ===================
#
#
# 站名:文化白雲公園
# 總量:68
# 可借:36
# 時間:20220528115419
# ===================
#
#
# 站名:秀山國小
# 總量:62
# 可借:48
# 時間:20220528115423
# ===================
#
#
# 站名:捷運永安市場站
# 總量:60
# 可借:17
# 時間:20220528115443
# ===================
#
#
# 站名:福和國中
# 總量:58
# 可借:0
# 時間:20220408132941
# ===================
#
#
# 站名:仁愛公園
# 總量:60
# 可借:37
# 時間:20220528115420
# ===================
#
#
# 站名:中和公園
# 總量:44
# 可借:24
# 時間:20220528115425
# ===================

# %%
import requests
response = requests.get('https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json/preview')
print(response.__class__)
response.url
# Out:
# <class 'requests.models.Response'>
# 'https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json/preview'
